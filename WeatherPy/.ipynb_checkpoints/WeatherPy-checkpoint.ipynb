# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy import stats
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

url = "https://api.openweathermap.org/data/2.5/weather?"

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city 
    

# Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["timezone"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kelaat mgouna
# City not found. Skipping...
# Processing Record 2 of Set 1 | atafu village
# Processing Record 3 of Set 1 | kapuskasing
# Processing Record 4 of Set 1 | fort bragg
# Processing Record 5 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | lerwick
# Processing Record 9 of Set 1 | puerto natales
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | adamstown
# Processing Record 12 of Set 1 | acapulco de juarez
# Processing Record 13 of Set 1 | padangsidempuan
# Processing Record 14 of Set 1 | vega de alatorre
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | invercargill
# Processing Record 17 of Set 1 | tobruk
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | grytviken
# Processing Record 20 of Set 1 | ambatofinandrahana
# Processing Record 21 of Set 1 | malanje
# Processing Record 22 of Set 1 | tucurui
# Processing Record 23 of Set 1 | colonia
# Processing Record 24 of Set 1 | whitehorse
# Processing Record 25 of Set 1 | maragogi
# Processing Record 26 of Set 1 | berezovyy
# Processing Record 27 of Set 1 | turbat
# Processing Record 28 of Set 1 | turpan
# Processing Record 29 of Set 1 | conde
# Processing Record 30 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 31 of Set 1 | yuzhno-kurilsk
# Processing Record 32 of Set 1 | tasqala
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | sudislavl'
# Processing Record 36 of Set 1 | uturoa
# Processing Record 37 of Set 1 | kingston
# Processing Record 38 of Set 1 | rongelap
# Processing Record 39 of Set 1 | nova sintra
# Processing Record 40 of Set 1 | dudinka
# Processing Record 41 of Set 1 | udachny
# Processing Record 42 of Set 1 | los chavez
# Processing Record 43 of Set 1 | lihue
# Processing Record 44 of Set 1 | richards bay
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | fauske
# Processing Record 47 of Set 1 | praia
# Processing Record 48 of Set 1 | laojunmiao
# Processing Record 49 of Set 1 | chibougamau
# Processing Record 50 of Set 1 | bethel
# Processing Record 0 of Set 2 | nong phai
# Processing Record 1 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | edinburgh of the seven seas
# Processing Record 4 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 5 of Set 2 | port-aux-francais
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | west island
# Processing Record 8 of Set 2 | lodja
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | timimoun
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | margaret river
# Processing Record 14 of Set 2 | guiyang
# Processing Record 15 of Set 2 | bilibino
# Processing Record 16 of Set 2 | garh maharaja
# Processing Record 17 of Set 2 | labrador city
# Processing Record 18 of Set 2 | villa regina
# Processing Record 19 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 20 of Set 2 | ullal
# Processing Record 21 of Set 2 | aasiaat
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | vilyuysk
# Processing Record 24 of Set 2 | suva
# Processing Record 25 of Set 2 | papatowai
# Processing Record 26 of Set 2 | anadyr
# Processing Record 27 of Set 2 | callaway
# Processing Record 28 of Set 2 | antsiranana
# Processing Record 29 of Set 2 | tsiombe
# Processing Record 30 of Set 2 | flying fish cove
# Processing Record 31 of Set 2 | hawaiian paradise park
# Processing Record 32 of Set 2 | san andres
# Processing Record 33 of Set 2 | taltal
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | quibala
# Processing Record 36 of Set 2 | miyaly
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 39 of Set 2 | nemuro
# Processing Record 40 of Set 2 | ola
# Processing Record 41 of Set 2 | okakarara
# Processing Record 42 of Set 2 | harstad
# Processing Record 43 of Set 2 | shanhaiguan
# Processing Record 44 of Set 2 | hirara
# Processing Record 45 of Set 2 | waspan
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | salinopolis
# Processing Record 48 of Set 2 | crane
# Processing Record 49 of Set 2 | tralee
# Processing Record 0 of Set 3 | guichon
# Processing Record 1 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 3 | lorengau
# Processing Record 3 of Set 3 | greymouth
# Processing Record 4 of Set 3 | santa vitoria do palmar
# Processing Record 5 of Set 3 | little cayman
# City not found. Skipping...
# Processing Record 6 of Set 3 | vorgashor
# Processing Record 7 of Set 3 | fort irwin
# Processing Record 8 of Set 3 | barcelos
# Processing Record 9 of Set 3 | granja
# Processing Record 10 of Set 3 | kailua-kona
# Processing Record 11 of Set 3 | afaahiti
# Processing Record 12 of Set 3 | eagle river
# Processing Record 13 of Set 3 | capanema
# Processing Record 14 of Set 3 | bubaque
# Processing Record 15 of Set 3 | stanley
# Processing Record 16 of Set 3 | aizawl
# Processing Record 17 of Set 3 | chuzhou
# Processing Record 18 of Set 3 | weno
# Processing Record 19 of Set 3 | fale old settlement
# Processing Record 20 of Set 3 | oak bay
# Processing Record 21 of Set 3 | port mathurin
# Processing Record 22 of Set 3 | an ros
# Processing Record 23 of Set 3 | el granada
# Processing Record 24 of Set 3 | codrington
# Processing Record 25 of Set 3 | pangai
# Processing Record 26 of Set 3 | awjilah
# Processing Record 27 of Set 3 | am djarass
# City not found. Skipping...
# Processing Record 28 of Set 3 | dubbo
# Processing Record 29 of Set 3 | kyren
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | kozloduy
# Processing Record 32 of Set 3 | jagdalpur
# Processing Record 33 of Set 3 | santa rosa
# Processing Record 34 of Set 3 | keflavik
# Processing Record 35 of Set 3 | horta
# Processing Record 36 of Set 3 | nuku'alofa
# Processing Record 37 of Set 3 | pandan
# Processing Record 38 of Set 3 | olonkinbyen
# Processing Record 39 of Set 3 | la malbaie
# Processing Record 40 of Set 3 | san rafael del yuma
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | darwin
# Processing Record 43 of Set 3 | greenville
# Processing Record 44 of Set 3 | sanctuary point
# Processing Record 45 of Set 3 | la'ie
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | wailua homesteads
# Processing Record 48 of Set 3 | vilyuchinsk
# Processing Record 49 of Set 3 | khandyga
# Processing Record 0 of Set 4 | christchurch
# Processing Record 1 of Set 4 | haiku-pauwela
# Processing Record 2 of Set 4 | kapa'a
# Processing Record 3 of Set 4 | constantia
# Processing Record 4 of Set 4 | boysun
# Processing Record 5 of Set 4 | newman
# Processing Record 6 of Set 4 | port hueneme
# Processing Record 7 of Set 4 | buulobarde
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | guerrero negro
# Processing Record 10 of Set 4 | natal
# Processing Record 11 of Set 4 | olinda
# Processing Record 12 of Set 4 | badger
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | cabo san lucas
# Processing Record 15 of Set 4 | northam
# Processing Record 16 of Set 4 | sao vicente
# Processing Record 17 of Set 4 | mirny
# Processing Record 18 of Set 4 | parabel'
# Processing Record 19 of Set 4 | rupert
# Processing Record 20 of Set 4 | igarka
# Processing Record 21 of Set 4 | utrik
# Processing Record 22 of Set 4 | axim
# Processing Record 23 of Set 4 | kasungu
# Processing Record 24 of Set 4 | nizhniy odes
# Processing Record 25 of Set 4 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 26 of Set 4 | port alfred
# Processing Record 27 of Set 4 | tocopilla
# Processing Record 28 of Set 4 | minas de marcona
# Processing Record 29 of Set 4 | santa helena de goias
# Processing Record 30 of Set 4 | margate
# Processing Record 31 of Set 4 | katsuren-haebaru
# Processing Record 32 of Set 4 | vila franca do campo
# Processing Record 33 of Set 4 | mount gambier
# Processing Record 34 of Set 4 | homer
# Processing Record 35 of Set 4 | hadibu
# Processing Record 36 of Set 4 | hasaki
# Processing Record 37 of Set 4 | sao paulo de olivenca
# Processing Record 38 of Set 4 | karratha
# Processing Record 39 of Set 4 | oranjemund
# Processing Record 40 of Set 4 | nossa senhora da gloria
# Processing Record 41 of Set 4 | qaqortoq
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | tirebolu
# Processing Record 44 of Set 4 | vadso
# Processing Record 45 of Set 4 | amungan
# Processing Record 46 of Set 4 | aioun
# Processing Record 47 of Set 4 | cabedelo
# Processing Record 48 of Set 4 | amga
# Processing Record 49 of Set 4 | tura
# Processing Record 0 of Set 5 | enewetak
# Processing Record 1 of Set 5 | as sulayyil
# Processing Record 2 of Set 5 | joao camara
# Processing Record 3 of Set 5 | finale ligure
# Processing Record 4 of Set 5 | trairi
# Processing Record 5 of Set 5 | abraham's bay
# City not found. Skipping...
# Processing Record 6 of Set 5 | kone
# Processing Record 7 of Set 5 | vila do maio
# Processing Record 8 of Set 5 | ulsteinvik
# Processing Record 9 of Set 5 | makurazaki
# Processing Record 10 of Set 5 | timbuktu
# Processing Record 11 of Set 5 | cidade velha
# Processing Record 12 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 13 of Set 5 | fortuna
# Processing Record 14 of Set 5 | port glaud
# City not found. Skipping...
# Processing Record 15 of Set 5 | rio gallegos
# Processing Record 16 of Set 5 | polovinnoye
# Processing Record 17 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 5 | saudarkrokur
# Processing Record 19 of Set 5 | svetlyy
# Processing Record 20 of Set 5 | inirida
# Processing Record 21 of Set 5 | inongo
# Processing Record 22 of Set 5 | upington
# Processing Record 23 of Set 5 | saint-philippe
# Processing Record 24 of Set 5 | fukagawa
# Processing Record 25 of Set 5 | cruzeiro do sul
# Processing Record 26 of Set 5 | coquimbo
# Processing Record 27 of Set 5 | mount pearl
# Processing Record 28 of Set 5 | tazovsky
# Processing Record 29 of Set 5 | coahuayana de hidalgo
# Processing Record 30 of Set 5 | kristiansund
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | alo
# Processing Record 34 of Set 5 | ciudad gustavo diaz ordaz
# Processing Record 35 of Set 5 | lazaro cardenas
# Processing Record 36 of Set 5 | nurota
# Processing Record 37 of Set 5 | vorkuta
# Processing Record 38 of Set 5 | treasure island
# Processing Record 39 of Set 5 | budva
# Processing Record 40 of Set 5 | fannuj
# City not found. Skipping...
# Processing Record 41 of Set 5 | inarajan village
# Processing Record 42 of Set 5 | ust'-ilimsk
# Processing Record 43 of Set 5 | altai
# Processing Record 44 of Set 5 | betio village
# Processing Record 45 of Set 5 | woolgoolga
# Processing Record 46 of Set 5 | chonchi
# Processing Record 47 of Set 5 | enshi
# Processing Record 48 of Set 5 | dilling
# Processing Record 49 of Set 5 | westport
# Processing Record 0 of Set 6 | hamilton
# Processing Record 1 of Set 6 | la toma
# Processing Record 2 of Set 6 | ust-nera
# Processing Record 3 of Set 6 | trincomalee
# Processing Record 4 of Set 6 | iskateley
# Processing Record 5 of Set 6 | kuraymah
# Processing Record 6 of Set 6 | tekeli
# Processing Record 7 of Set 6 | villa de soto
# Processing Record 8 of Set 6 | manato
# City not found. Skipping...
# Processing Record 9 of Set 6 | rabo de peixe
# Processing Record 10 of Set 6 | drahichyn
# Processing Record 11 of Set 6 | tanout
# Processing Record 12 of Set 6 | thompson
# Processing Record 13 of Set 6 | severo-yeniseyskiy
# Processing Record 14 of Set 6 | kavieng
# Processing Record 15 of Set 6 | tual
# Processing Record 16 of Set 6 | freetown
# Processing Record 17 of Set 6 | ngama
# Processing Record 18 of Set 6 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 19 of Set 6 | leava
# Processing Record 20 of Set 6 | lillesand
# Processing Record 21 of Set 6 | sanghar
# Processing Record 22 of Set 6 | sinabang
# Processing Record 23 of Set 6 | atherton
# Processing Record 24 of Set 6 | jamestown
# Processing Record 25 of Set 6 | tangalle
# Processing Record 26 of Set 6 | bulakamba
# Processing Record 27 of Set 6 | zeya
# Processing Record 28 of Set 6 | progreso
# Processing Record 29 of Set 6 | port blair
# Processing Record 30 of Set 6 | nephi
# Processing Record 31 of Set 6 | entre rios
# Processing Record 32 of Set 6 | cooper's town
# Processing Record 33 of Set 6 | saipan
# Processing Record 34 of Set 6 | buenos aires
# Processing Record 35 of Set 6 | isafjordur
# Processing Record 36 of Set 6 | bolobo
# Processing Record 37 of Set 6 | la passe
# Processing Record 38 of Set 6 | portland
# Processing Record 39 of Set 6 | st. john's
# Processing Record 40 of Set 6 | happy valley-goose bay
# Processing Record 41 of Set 6 | alakurtti
# Processing Record 42 of Set 6 | klyuchi
# Processing Record 43 of Set 6 | hastings
# Processing Record 44 of Set 6 | usinsk
# Processing Record 45 of Set 6 | laghouat
# Processing Record 46 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 47 of Set 6 | la puebla de montalban
# Processing Record 48 of Set 6 | miches
# Processing Record 49 of Set 6 | bardai
# Processing Record 0 of Set 7 | tete
# Processing Record 1 of Set 7 | male
# Processing Record 2 of Set 7 | banamba
# Processing Record 3 of Set 7 | ertil'
# Processing Record 4 of Set 7 | souillac
# Processing Record 5 of Set 7 | peto
# Processing Record 6 of Set 7 | kichmengskiy gorodok
# Processing Record 7 of Set 7 | harij
# Processing Record 8 of Set 7 | verkhnedneprovskiy
# Processing Record 9 of Set 7 | gadzhiyevo
# Processing Record 10 of Set 7 | ariquemes
# Processing Record 11 of Set 7 | fort leonard wood
# Processing Record 12 of Set 7 | mount isa
# Processing Record 13 of Set 7 | ise-ekiti
# Processing Record 14 of Set 7 | ahoada
# Processing Record 15 of Set 7 | oyama
# Processing Record 16 of Set 7 | nagqu
# Processing Record 17 of Set 7 | lata
# Processing Record 18 of Set 7 | raduzhnyy
# Processing Record 19 of Set 7 | tezu
# Processing Record 20 of Set 7 | arar
# Processing Record 21 of Set 7 | kultali
# City not found. Skipping...
# Processing Record 22 of Set 7 | boa vista
# Processing Record 23 of Set 7 | tecate
# Processing Record 24 of Set 7 | mount pleasant
# Processing Record 25 of Set 7 | chimbarongo
# Processing Record 26 of Set 7 | kamensk-ural'skiy
# Processing Record 27 of Set 7 | peace river
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | katsuura
# Processing Record 30 of Set 7 | al wafrah
# Processing Record 31 of Set 7 | pechora
# Processing Record 32 of Set 7 | ribeira brava
# Processing Record 33 of Set 7 | dolores
# Processing Record 34 of Set 7 | tulagi
# Processing Record 35 of Set 7 | es castell
# Processing Record 36 of Set 7 | medjez el bab
# Processing Record 37 of Set 7 | antalaha
# Processing Record 38 of Set 7 | xinguara
# City not found. Skipping...
# Processing Record 39 of Set 7 | ndjole
# Processing Record 40 of Set 7 | nhlangano
# Processing Record 41 of Set 7 | santanyi
# Processing Record 42 of Set 7 | tagta
# Processing Record 43 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 44 of Set 7 | nizhnesortymskiy
# Processing Record 45 of Set 7 | mulayjah
# Processing Record 46 of Set 7 | port shepstone
# Processing Record 47 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 7 | ahmadpur east
# Processing Record 49 of Set 7 | eregli
# Processing Record 0 of Set 8 | jiexiu
# Processing Record 1 of Set 8 | nadi
# Processing Record 2 of Set 8 | corcoran
# Processing Record 3 of Set 8 | labuan
# Processing Record 4 of Set 8 | asau village
# City not found. Skipping...
# Processing Record 5 of Set 8 | tolanaro
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | constanza
# Processing Record 8 of Set 8 | namibe
# Processing Record 9 of Set 8 | hithadhoo
# Processing Record 10 of Set 8 | puerto baquerizo moreno
# Processing Record 11 of Set 8 | ganshui
# Processing Record 12 of Set 8 | nikolayevsk-on-amure
# Processing Record 13 of Set 8 | ha'il
# Processing Record 14 of Set 8 | zanjan
# Processing Record 15 of Set 8 | lebu
# Processing Record 16 of Set 8 | port hedland
# Processing Record 17 of Set 8 | katsina-ala
# Processing Record 18 of Set 8 | quepos
# Processing Record 19 of Set 8 | saint croix
# Processing Record 20 of Set 8 | arroio dos ratos
# Processing Record 21 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 22 of Set 8 | brynmawr
# Processing Record 23 of Set 8 | assab
# Processing Record 24 of Set 8 | wurzburg
# Processing Record 25 of Set 8 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 26 of Set 8 | coari
# Processing Record 27 of Set 8 | tazacorte
# Processing Record 28 of Set 8 | trinidad
# Processing Record 29 of Set 8 | college
# Processing Record 30 of Set 8 | nowy tomysl
# Processing Record 31 of Set 8 | san pedro pochutla
# Processing Record 32 of Set 8 | bikenibeu village
# Processing Record 33 of Set 8 | patterson
# Processing Record 34 of Set 8 | shalqar
# Processing Record 35 of Set 8 | laboulaye
# Processing Record 36 of Set 8 | quellon
# Processing Record 37 of Set 8 | palmer
# Processing Record 38 of Set 8 | san luis de la loma
# Processing Record 39 of Set 8 | sos'va
# Processing Record 40 of Set 8 | stung treng
# Processing Record 41 of Set 8 | hammerfest
# Processing Record 42 of Set 8 | vila velha
# Processing Record 43 of Set 8 | quesnel
# Processing Record 44 of Set 8 | kyshtovka
# Processing Record 45 of Set 8 | nyurba
# Processing Record 46 of Set 8 | kushiro
# Processing Record 47 of Set 8 | kembe
# Processing Record 48 of Set 8 | meadow lake
# Processing Record 49 of Set 8 | talitsa
# Processing Record 0 of Set 9 | sur
# Processing Record 1 of Set 9 | badagry
# Processing Record 2 of Set 9 | agat village
# Processing Record 3 of Set 9 | tommot
# Processing Record 4 of Set 9 | egilsstadir
# Processing Record 5 of Set 9 | coyhaique
# Processing Record 6 of Set 9 | albertina
# Processing Record 7 of Set 9 | essaouira
# Processing Record 8 of Set 9 | morshansk
# Processing Record 9 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 10 of Set 9 | svidnik
# Processing Record 11 of Set 9 | mhamid
# Processing Record 12 of Set 9 | murun-kuren
# Processing Record 13 of Set 9 | vikulovo
# Processing Record 14 of Set 9 | camacupa
# Processing Record 15 of Set 9 | charters towers
# Processing Record 16 of Set 9 | airuk
# Processing Record 17 of Set 9 | mirpur sakro
# Processing Record 18 of Set 9 | beau vallon
# Processing Record 19 of Set 9 | quimili
# Processing Record 20 of Set 9 | magistral'nyy
# Processing Record 21 of Set 9 | sint michiel liber
# Processing Record 22 of Set 9 | mandleshwar
# Processing Record 23 of Set 9 | talnakh
# Processing Record 24 of Set 9 | yerofey pavlovich
# Processing Record 25 of Set 9 | funadhoo
# Processing Record 26 of Set 9 | tadine
# Processing Record 27 of Set 9 | pompeu
# Processing Record 28 of Set 9 | chernyshevskiy
# Processing Record 29 of Set 9 | port lincoln
# Processing Record 30 of Set 9 | eirunepe
# Processing Record 31 of Set 9 | aripuana
# Processing Record 32 of Set 9 | zuni pueblo
# Processing Record 33 of Set 9 | pedernales
# Processing Record 34 of Set 9 | prado
# Processing Record 35 of Set 9 | avsallar
# Processing Record 36 of Set 9 | sabang
# Processing Record 37 of Set 9 | nsanje
# Processing Record 38 of Set 9 | halifax
# Processing Record 39 of Set 9 | pangkalanbuun
# Processing Record 40 of Set 9 | madang
# Processing Record 41 of Set 9 | buka
# Processing Record 42 of Set 9 | sarangpur
# Processing Record 43 of Set 9 | port saint john's
# Processing Record 44 of Set 9 | longgang
# Processing Record 45 of Set 9 | kiruna
# Processing Record 46 of Set 9 | ji'an
# Processing Record 47 of Set 9 | ponnur
# Processing Record 48 of Set 9 | mugumu
# Processing Record 49 of Set 9 | beyneu
# Processing Record 0 of Set 10 | thunder bay
# Processing Record 1 of Set 10 | auki
# Processing Record 2 of Set 10 | ijuw
# City not found. Skipping...
# Processing Record 3 of Set 10 | kenora
# Processing Record 4 of Set 10 | alice springs
# Processing Record 5 of Set 10 | mil'kovo
# Processing Record 6 of Set 10 | kewarra beach
# City not found. Skipping...
# Processing Record 7 of Set 10 | pacifica
# Processing Record 8 of Set 10 | gisborne
# Processing Record 9 of Set 10 | karaidel'
# Processing Record 10 of Set 10 | sao joao da barra
# Processing Record 11 of Set 10 | bitola
# Processing Record 12 of Set 10 | rukban
# City not found. Skipping...
# Processing Record 13 of Set 10 | wynyard
# Processing Record 14 of Set 10 | gizo
# Processing Record 15 of Set 10 | cururupu
# Processing Record 16 of Set 10 | kerema
# Processing Record 17 of Set 10 | north platte
# Processing Record 18 of Set 10 | ust-kamenogorsk
# Processing Record 19 of Set 10 | lospalos
# Processing Record 20 of Set 10 | whangarei
# Processing Record 21 of Set 10 | newnham
# Processing Record 22 of Set 10 | watsa
# Processing Record 23 of Set 10 | broome
# Processing Record 24 of Set 10 | coracora
# Processing Record 25 of Set 10 | hami
# Processing Record 26 of Set 10 | mansa
# Processing Record 27 of Set 10 | juneau
# Processing Record 28 of Set 10 | corner brook
# Processing Record 29 of Set 10 | kaohsiung
# Processing Record 30 of Set 10 | ketchikan
# Processing Record 31 of Set 10 | mejit
# Processing Record 32 of Set 10 | susanville
# Processing Record 33 of Set 10 | palmerston north
# Processing Record 34 of Set 10 | porto de moz
# Processing Record 35 of Set 10 | east london
# Processing Record 36 of Set 10 | sabancuy
# Processing Record 37 of Set 10 | susuman
# Processing Record 38 of Set 10 | thurso
# Processing Record 39 of Set 10 | dawson creek
# Processing Record 40 of Set 10 | tuy hoa
# Processing Record 41 of Set 10 | constitucion
# Processing Record 42 of Set 10 | claremont
# Processing Record 43 of Set 10 | saint-louis
# Processing Record 44 of Set 10 | salekhard
# Processing Record 45 of Set 10 | al kharj
# Processing Record 46 of Set 10 | linares
# Processing Record 47 of Set 10 | jaicos
# Processing Record 48 of Set 10 | dryden
# Processing Record 49 of Set 10 | touros
# Processing Record 0 of Set 11 | devils lake
# Processing Record 1 of Set 11 | tchintabaraden
# Processing Record 2 of Set 11 | malvan
# Processing Record 3 of Set 11 | herceg novi
# Processing Record 4 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 5 of Set 11 | palu
# Processing Record 6 of Set 11 | santa rosa del sara
# City not found. Skipping...
# Processing Record 7 of Set 11 | castelli
# Processing Record 8 of Set 11 | saldanha
# Processing Record 9 of Set 11 | kayangel
# Processing Record 10 of Set 11 | cruz del eje
# Processing Record 11 of Set 11 | bluefield
# Processing Record 12 of Set 11 | mammoth lakes
# Processing Record 13 of Set 11 | brookings
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | kapsowar
# City not found. Skipping...
# Processing Record 16 of Set 11 | huilong
# Processing Record 17 of Set 11 | nelidovo
# Processing Record 18 of Set 11 | borzna
# Processing Record 19 of Set 11 | uniontown
# Processing Record 20 of Set 11 | ciudad lazaro cardenas
# Processing Record 21 of Set 11 | aibak
# Processing Record 22 of Set 11 | san salvador de jujuy
# Processing Record 23 of Set 11 | macusani
# Processing Record 24 of Set 11 | viedma
# Processing Record 25 of Set 11 | el fuerte
# Processing Record 26 of Set 11 | shache
# Processing Record 27 of Set 11 | remire-montjoly
# Processing Record 28 of Set 11 | klahanie
# Processing Record 29 of Set 11 | noosa heads
# Processing Record 30 of Set 11 | lalibela
# Processing Record 31 of Set 11 | orange walk
# Processing Record 32 of Set 11 | tarawa
# Processing Record 33 of Set 11 | tak
# Processing Record 34 of Set 11 | concepcion del oro
# Processing Record 35 of Set 11 | marsh harbour
# Processing Record 36 of Set 11 | monrovia
# Processing Record 37 of Set 11 | altar
# Processing Record 38 of Set 11 | aroma
# Processing Record 39 of Set 11 | villa del totoral
# Processing Record 40 of Set 11 | alofi
# Processing Record 41 of Set 11 | slave lake
# Processing Record 42 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 43 of Set 11 | mata-utu
# Processing Record 44 of Set 11 | malmesbury
# Processing Record 45 of Set 11 | planaltina
# Processing Record 46 of Set 11 | claveria
# Processing Record 47 of Set 11 | bien unido
# Processing Record 48 of Set 11 | jackson
# Processing Record 49 of Set 11 | saynshand
# Processing Record 0 of Set 12 | santa cruz
# Processing Record 1 of Set 12 | malango
# Processing Record 2 of Set 12 | neiafu
# Processing Record 3 of Set 12 | mount vernon
# Processing Record 4 of Set 12 | barra de santo antonio
# Processing Record 5 of Set 12 | czaplinek
# Processing Record 6 of Set 12 | koelwar
# Processing Record 7 of Set 12 | kotlas
# Processing Record 8 of Set 12 | huatabampo
# Processing Record 9 of Set 12 | necochea
# Processing Record 10 of Set 12 | phuthaditjhaba
# Processing Record 11 of Set 12 | seydi
# Processing Record 12 of Set 12 | papao
# Processing Record 13 of Set 12 | nuuk
# Processing Record 14 of Set 12 | soroti
# Processing Record 15 of Set 12 | shajiang
# Processing Record 16 of Set 12 | modimolle
# Processing Record 17 of Set 12 | baker city
# Processing Record 18 of Set 12 | nyamira
# Processing Record 19 of Set 12 | beloyarskiy
# Processing Record 20 of Set 12 | daru
# Processing Record 21 of Set 12 | shingu
# Processing Record 22 of Set 12 | rosario do sul
# Processing Record 23 of Set 12 | cabaritan east
# Processing Record 24 of Set 12 | mao
# Processing Record 25 of Set 12 | al marj
# Processing Record 26 of Set 12 | faya-largeau
# Processing Record 27 of Set 12 | pulawy
# Processing Record 28 of Set 12 | hotan
# Processing Record 29 of Set 12 | hell-ville
# Processing Record 30 of Set 12 | bridlington
# Processing Record 31 of Set 12 | port macquarie
# Processing Record 32 of Set 12 | ibia
# Processing Record 33 of Set 12 | al ghayzah
# Processing Record 34 of Set 12 | sokoni
# Processing Record 35 of Set 12 | guigang
# Processing Record 36 of Set 12 | xucheng
# Processing Record 37 of Set 12 | yamada
# Processing Record 38 of Set 12 | midvagur
# Processing Record 39 of Set 12 | birobidzhan
# Processing Record 40 of Set 12 | pangoa
# Processing Record 41 of Set 12 | piti village
# Processing Record 42 of Set 12 | mahajanga
# Processing Record 43 of Set 12 | quixada
# Processing Record 44 of Set 12 | zhezqazghan
# Processing Record 45 of Set 12 | bushland beach
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  atafu village  -8.5421 -172.5159    303.42        75          78
# 1    kapuskasing  49.4169  -82.4331    282.20        93         100
# 2     fort bragg  35.1390  -79.0060    294.16        66         100
# 3         avarua -21.2078 -159.7750    299.18        89          75
# 4         albany  42.6001  -73.9662    296.38        50          51
#
#    Wind Speed Country   Date
# 0        7.24      TK  46800
# 1        1.03      CA -14400
# 2        6.69      US -14400
# 3        6.69      CK -36000
# 4        1.79      US -14400

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        atafu village  -8.5421 -172.5159    303.42        75          78
# 1          kapuskasing  49.4169  -82.4331    282.20        93         100
# 2           fort bragg  35.1390  -79.0060    294.16        66         100
# 3               avarua -21.2078 -159.7750    299.18        89          75
# 4               albany  42.6001  -73.9662    296.38        50          51
#
#          Wind Speed Country   Date
# City_ID
# 0              7.24      TK  46800
# 1              1.03      CA -14400
# 2              6.69      US -14400
# 3              6.69      CK -36000
# 4              1.79      US -14400

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values= city_data_df["Lat"]
y_values = city_data_df["Humidity"]
plt.scatter(x_values,y_values)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]
plt.scatter(x_values,y_values)


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(regress_values)

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# City_ID
# 0      4.076446
# 1      3.765670
# 2      3.842228
# 3      4.144360
# 4      3.802222
#          ...
# 557    4.095613
# 558    3.958457
# 559    4.114917
# 560    4.057300
# 561    3.774429
# Name: Lat, Length: 562, dtype: float64
# y = -0.01x +4.03

# %%
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.004172606960085977

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_lat=[]
for x in city_data_df["Lat"]:
    if x >= 0:
      northern_hemi_lat.append(x)
northern_hemi_lat_df = pd.DataFrame(northern_hemi_lat)
northern_hemi_lat_df = northern_hemi_lat_df.rename(columns={0: 'Lat'})
northern_hemi_lat_df.head()
# Out:
#        Lat
# 0  49.4169
# 1  35.1390
# 2  42.6001
# 3  60.1545
# 4  16.8634

# %%
# Display sample data
northern_hemi_df = pd.merge(city_data_df, northern_hemi_lat_df, on = "Lat")
northern_hemi_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           kapuskasing  49.4169  -82.4331    282.20        93         100
# 1            fort bragg  35.1390  -79.0060    294.16        66         100
# 2                albany  42.6001  -73.9662    296.38        50          51
# 3               lerwick  60.1545   -1.1494    280.15        86         100
# 4    acapulco de juarez  16.8634  -99.8901    301.05        74           0
# ..                  ...      ...       ...       ...       ...         ...
# 377              yamada  39.4667  141.9500    276.92        60           3
# 378            midvagur  62.0511   -7.1939    277.61        81          40
# 379         birobidzhan  48.8000  132.9500    274.72        48           7
# 380        piti village  13.4626  144.6933    301.32        86         100
# 381         zhezqazghan  47.7833   67.7667    283.73        79          86
#
#      Wind Speed Country   Date
# 0          1.03      CA -14400
# 1          6.69      US -14400
# 2          1.79      US -14400
# 3          7.39      GB   3600
# 4          7.20      MX -21600
# ..          ...     ...    ...
# 377        1.81      JP  32400
# 378        1.54      FO   3600
# 379        2.47      RU  36000
# 380        6.77      GU  36000
# 381        8.41      KZ  18000
#
# [382 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_lat=[]
for x in city_data_df["Lat"]:
    if x < 0:
      southern_hemi_lat.append(x)
southern_hemi_lat_df = pd.DataFrame(southern_hemi_lat)
southern_hemi_lat_df = southern_hemi_lat_df.rename(columns={0: 'Lat'})
southern_hemi_lat_df.head()
# Out:
#        Lat
# 0  -8.5421
# 1 -21.2078
# 2 -51.7236
# 3 -24.8667
# 4 -25.0660

# %%
# Display sample data
southern_hemi_df = pd.merge(city_data_df, southern_hemi_lat_df, on = "Lat")
southern_hemi_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     atafu village  -8.5421 -172.5159    303.42        75          78
# 1            avarua -21.2078 -159.7750    299.18        89          75
# 2    puerto natales -51.7236  -72.4875    282.40        53          40
# 3         carnarvon -24.8667  113.6333    298.18        41           0
# 4         adamstown -25.0660 -130.1015    296.80        79          43
# ..              ...      ...       ...       ...       ...         ...
# 183            ibia -19.4783  -46.5389    296.85        75         100
# 184          sokoni  -6.4333   39.5500    299.41        86          89
# 185          pangoa -12.1167  -73.0000    297.78        95          96
# 186       mahajanga -15.7167   46.3167    300.16        94          20
# 187         quixada  -4.9714  -39.0153    297.32        95          99
#
#      Wind Speed Country   Date
# 0          7.24      TK  46800
# 1          6.69      CK -36000
# 2         10.29      CL -10800
# 3          6.45      AU  28800
# 4          2.08      PN -28800
# ..          ...     ...    ...
# 183        1.60      BR -10800
# 184        4.88      TZ  10800
# 185        0.86      PE -18000
# 186        1.03      MG  10800
# 187        1.84      BR -10800
#
# [188 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Build scatter plot for latitude vs. temperature
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept


line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = -0.61x +310.14
# The r-value is: 0.7225715077814662

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.33x +301.78
# The r-value is: 0.506845338681111

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.34x +54.75
# The r-value is: 0.06870096706991617

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.43x +87.87
# The r-value is: 0.1433066524452437

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.27x +49.46
# The r-value is: 0.01809843386638644

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.63x +79.57
# The r-value is: 0.061728513086173706

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = -0.02x +4.76
# The r-value is: 0.019546082850438035

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = -0.08x +2.07
# The r-value is: 0.13815759312423967

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
